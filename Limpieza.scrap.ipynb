# %%
import os
import pandas as pd
from tqdm import tqdm
pd.set_option('display.max_columns', None) # para poder visualizar todas las columnas de los DataFrames
import warnings
warnings.filterwarnings("ignore")
import zipfile
import shutil
import re
import sys
import json
sys.path.append("../")
from src import soporte_analisis as st

# %%
try:
    df = pd.read_csv('datos/scrap/03001.csv', encoding='latin1', sep=';')

except UnicodeDecodeError: 
    df = pd.read_csv('datos/scrap/03001.csv', encoding='utf-8', errors='ignore')
    df['Total'] = df['Total'].str.replace('.','').astype(int)

# %%
try:
    df_pib = pd.read_csv('datos/scrap/67284.csv', encoding='latin1', sep=';')

except UnicodeDecodeError: 
   df_pib = pd.read_csv('datos/scrap/67284.csv', encoding='utf-8', errors='ignore')
   
df_pib ['Total'] = df_pib['Total'].str.replace('.','').astype(int)
df_pib ['periodo'] = df_pib['periodo'].str.replace('(P)','')

# %%
try:
    df_tot = pd.read_csv('datos/scrap/67285 (2).csv', encoding='latin1', sep=';')

except UnicodeDecodeError: 
   df_tot = pd.read_csv('datos/scrap/67285 (2).csv', encoding='utf-8', errors='ignore')

# %%
df_tot.head(2)
# Out:
#     Provincias Ramas de actividad                          Magnitud  periodo  \
# 0  02 Albacete     TOTAL PERSONAS  Empleo total (miles de personas)  2021(P)
# 1  02 Albacete     TOTAL PERSONAS  Empleo total (miles de personas)     2020
#
#    Total
# 0  150,2
# 1  147,1

# %%
df_tot['Total'].unique()
df_tot['periodo'] = df_tot['periodo'].str.replace('(P)','')
df_tot['Total'] = df_tot['Total'].str.replace(',','.')

# %%
df_tot['Total'] = df_tot['Total'].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 df_tot['Total'] = df_tot['Total'].astype(float)
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File c:\Users\HP\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
df_tot
# Out:
#               Provincias Ramas de actividad                          Magnitud  \
# 0            02 Albacete     TOTAL PERSONAS  Empleo total (miles de personas)
# 1            02 Albacete     TOTAL PERSONAS  Empleo total (miles de personas)
# 2    03 Alicante/Alacant     TOTAL PERSONAS  Empleo total (miles de personas)
# 3    03 Alicante/Alacant     TOTAL PERSONAS  Empleo total (miles de personas)
# 4             04 Almería     TOTAL PERSONAS  Empleo total (miles de personas)
# ..                   ...                ...                               ...
# 99           50 Zaragoza     TOTAL PERSONAS  Empleo total (miles de personas)
# 100             51 Ceuta     TOTAL PERSONAS  Empleo total (miles de personas)
# 101             51 Ceuta     TOTAL PERSONAS  Empleo total (miles de personas)
# 102           52 Melilla     TOTAL PERSONAS  Empleo total (miles de personas)
# 103           52 Melilla     TOTAL PERSONAS  Empleo total (miles de personas)
#
#      periodo  Total
# ...
